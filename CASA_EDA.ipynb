# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('credit_debit_preprocessed_transactions.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900000 entries, 0 to 899999
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0.1                 900000 non-null  int64
#  1   Unnamed: 0                   900000 non-null  int64
#  2   User                         900000 non-null  int64
#  3   Card                         900000 non-null  int64
#  4   Year                         900000 non-null  float64
#  5   Month                        900000 non-null  float64
#  6   Day                          900000 non-null  float64
#  7   Time                         900000 non-null  object
#  8   Amount                       900000 non-null  float64
#  9   Use Chip                     900000 non-null  object
#  10  Merchant Name                900000 non-null  float64
#  11  Merchant City                900000 non-null  object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  User  Card    Year  Month  Day   Time  Amount  \
# 0             0           0     0     0  2002.0    9.0  1.0  06:21  134.09
# 1             1           1     0     0  2002.0    9.0  1.0  06:42   38.48
# 2             2           2     0     0  2002.0    9.0  2.0  06:22  120.34
# 3             3           3     0     0  2002.0    9.0  2.0  17:45  128.95
# 4             4           4     0     0  2002.0    9.0  3.0  06:23  104.71
#
#             Use Chip  ...  user_City user_State user_Zipcode  user_Latitude  \
# 0  Swipe Transaction  ...   La Verne         CA        91750          34.15
# 1  Swipe Transaction  ...   La Verne         CA        91750          34.15
# 2  Swipe Transaction  ...   La Verne         CA        91750          34.15
# 3  Swipe Transaction  ...   La Verne         CA        91750          34.15
# 4  Swipe Transaction  ...   La Verne         CA        91750          34.15
#
# ...
